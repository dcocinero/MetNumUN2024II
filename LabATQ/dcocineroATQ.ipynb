# %% [markdown]
# <a href="https://colab.research.google.com/github/dcocinero/MetNumUN2024II/blob/main/LabATQ/dcocineroATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modificaciones:
#
# ##Variables adicionales
# ###SMA:
# el SMA (Simple Moving Average) sirve para simplificar la información contenida en series de tiempo, calculo el promedio en estas series, en este caso de 20 días.
#
# ![image.png](data:image/png;base64,...)
# ###OBV
# El OBV (On Balance Volume) utiliza el volumen de negociación para ayudar a confirmar o anticipar tendencias en el precio de un activo.![image.png](data:image/png;base64,...)
#
# ###TRIX
# Trix ayuda a identificar cambios en la tendencia de un activo calculando una media móvil exponencial (EMA) tres veces sobre la serie de precios.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Modelo
# ![image.png](data:image/png;base64,...)
#
# ## Sistema de compra/venta
#
# Como se puede ver el modelo elige si compra, vende o no hace nada según que tanto varia el precio del dia anterior a el dia actual.
#
# ![image.png](data:image/png;base64,...)
#
# ## Sharp ratio
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Assests
#
# Solo assests liquidos
#
# ![image.png](data:image/png;base64,...)
#
# El modelo se corrio con todos lo assets pero los assets escogidos fueron los siguientes:
#
# ![image.png](data:image/png;base64,...)
